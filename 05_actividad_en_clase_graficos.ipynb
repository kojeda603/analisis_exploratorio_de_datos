# %% [markdown]
# <a href="https://colab.research.google.com/github/kojeda603/analisis_exploratorio_de_datos/blob/main/05_actividad_en_clase_graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://github.com/Gustavo-Bruges/ciencia-de-datos-unab/raw/refs/heads/datos/olympics.zip")

# %%
departamentos = ['santander','atlantico','norte de santander']
capitales = ['Bucaramanga','Barranquilla','cucuta']

# %%
print(type(departamentos))
# Out:
# <class 'list'>

# %%
colombia = dict(zip(departamentos,capitales))

# %%
colombia
# Out:
# {'santander': 'Bucaramanga',
#  'atlantico': 'Barranquilla',
#  'norte de santander': 'cucuta'}

# %%
colombia['santander']
# Out:
# 'Bucaramanga'

# %%
colombia['Valle del Cauca'] = 'cali'

# %%
colombia
# Out:
# {'santander': 'Bucaramanga',
#  'atlantico': 'Barranquilla',
#  'norte de santander': 'cucuta',
#  'Valle del Cauca': 'cali'}

# %%
for i in colombia:
  print(i)
# Out:
# santander
# atlantico
# norte de santander
# Valle del Cauca

# %%
for dep,cap in colombia.items():
  print(dep,cap)
# Out:
# santander Bucaramanga
# atlantico Barranquilla
# norte de santander cucuta
# Valle del Cauca cali

# %%
municipios = ['Floridablanca', 'giron', 'piedecuesta']

# %%
entidades = {'santander': municipios}

# %%
entidades
# Out:
# {'santander': ['Floridablanca', 'giron', 'piedecuesta']}

# %%
entidades['santander'][0]
# Out:
# 'Floridablanca'

# %%
entidades['santander'][0:3:2]
# Out:
# ['Floridablanca', 'piedecuesta']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  271116 non-null  int64
#  1   id          271116 non-null  int64
#  2   name        271116 non-null  object
#  3   sex         271116 non-null  object
#  4   age         261642 non-null  float64
#  5   height      210945 non-null  float64
#  6   weight      208241 non-null  float64
#  7   team        271116 non-null  object
#  8   noc         271116 non-null  object
#  9   games       271116 non-null  object
#  10  year        271116 non-null  int64
#  11  season      271116 non-null  object
#  12  city        271116 non-null  object
#  13  sport       271116 non-null  object
#  14  event       271116 non-null  object
#  15  medal       39783 non-null   object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 33.1+ MB

# %%
df['medal'].nbytes
# Out:
# 2168928

# %%
#convertir mi variable object a variable categorica

df['medal'] = df['medal'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  271116 non-null  int64
#  1   id          271116 non-null  int64
#  2   name        271116 non-null  object
#  3   sex         271116 non-null  object
#  4   age         261642 non-null  float64
#  5   height      210945 non-null  float64
#  6   weight      208241 non-null  float64
#  7   team        271116 non-null  object
#  8   noc         271116 non-null  object
#  9   games       271116 non-null  object
#  10  year        271116 non-null  int64
#  11  season      271116 non-null  object
#  12  city        271116 non-null  object
#  13  sport       271116 non-null  object
#  14  event       271116 non-null  object
#  15  medal       39783 non-null   category
# dtypes: category(1), float64(3), int64(3), object(9)
# memory usage: 31.3+ MB

# %%
df['medal'].nbytes
# Out:
# 2168928

# %%
df['sex'].nbytes
# Out:
# 2168928

# %%
df['sex'] = df['sex'].astype('category')
df['sex'].nbytes
# Out:
# 271132

# %%
df['medal'].value_counts(normalize=True).round(2)*100
# Out:
# medal
# Gold      34.0
# Bronze    33.0
# Silver    33.0
# Name: proportion, dtype: float64

# %%
df['sex'].value_counts(normalize=True).round(2)*100
# Out:
# sex
# M    73.0
# F    27.0
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  271116 non-null  int64
#  1   id          271116 non-null  int64
#  2   name        271116 non-null  object
#  3   sex         271116 non-null  category
#  4   age         261642 non-null  float64
#  5   height      210945 non-null  float64
#  6   weight      208241 non-null  float64
#  7   team        271116 non-null  object
#  8   noc         271116 non-null  object
#  9   games       271116 non-null  object
#  10  year        271116 non-null  int64
#  11  season      271116 non-null  object
#  12  city        271116 non-null  object
#  13  sport       271116 non-null  object
#  14  event       271116 non-null  object
#  15  medal       39783 non-null   category
# dtypes: category(2), float64(3), int64(3), object(8)
# memory usage: 29.5+ MB

# %%
df.groupby('sex')['medal'].value_counts(normalize=True).round(2)*100
# Out:
# /tmp/ipykernel_183/924588797.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['medal'].value_counts(normalize=True).round(2)*100
# sex  medal
# F    Bronze    34.0
#      Gold      33.0
#      Silver    33.0
# M    Gold      34.0
#      Bronze    33.0
#      Silver    33.0
# Name: proportion, dtype: float64

# %%
df.groupby('sex')['age'].agg(['min','max','mean']).round(1)
# Out:
# /tmp/ipykernel_183/1818755138.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['age'].agg(['min','max','mean']).round(1)
#       min   max  mean
# sex
# F    11.0  74.0  23.7
# M    10.0  97.0  26.3

# %%
sns.pairplot(df)
plt.show()

# %%
sns.histplot(data=df, x='age')
plt.show()

# %%
df["age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(data=df, x='age',hue='sex',kde=True, bins = 15)
plt.show()

# %%
sns.catplot(data=df, x='sex', y='age', kind='box')
plt.show()

# %%
sns.catplot(data=df, x='sex', y='age',kind = 'bar', col = 'season', hue='sex')
plt.show()
